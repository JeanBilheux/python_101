# %% [markdown]
# # old style

# %%
name = 'Yanick'
value = 10454

# %%
print("Hey %s, there is a %d value" % (name, value))
# Out:
# Hey Yanick, there is a 10454 value

# %% [raw]
# or

# %% [markdown]
# Nice print using a dictionary

# %%
my_dict = {'name': 'Yanick', 'value': 10454}

# %%
print("Hey %(name)s, there is a %(value)d" % my_dict)
# Out:
# Hey Yanick, there is a 10454

# %% [markdown]
# # new style

# %%
my_dict = {'a':10, 'b': 20}

# %%
for key, value in my_dict.items():
    print("key/value is {0}/{1}".format(key, value))
# Out:
# key/value is b/20
# key/value is a/10

# %% [markdown]
# Nice tutorial about [PyFormat](https://pyformat.info/)

# %%
print("{object} and a={a}".format(object='hello', a=my_dict['a']))
# Out:
# hello and a=10

# %% [markdown]
# # new new style (starting with python 3.6)

# %%
name = 'Bob'

# %%
f"Hello, {name}!"
# Out:
#   File "<ipython-input-19-3bed004af2da>", line 1
#     f"Hello, {name}!"
#                     ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Template Strings

# %%
from string import Template
t = Template("this is my $name")

# %%
t.substitute(name="bob")
# Out:
# 'this is my bob'

# %% [markdown]
# The most useful way of using template strings is when we are handling format strings generated by users.
#
# Because they are less complex, the provide a safer choice.

# %% [markdown]
# **BAD**

# %%
SECRET = 'this-is-a-secret'
class Error:
    def __init__(self):
        pass

# %%
err = Error()

# %%
user_input = '{error.__init__.__globals__[SECRET]}'

# %%
user_input.format(error=err)
# Out:
# 'this-is-a-secret'

# %% [markdown]
# **BAD #2**

# %%
class MY_CLASS:
    a = 10
    def __init__(self):
        pass

# %%
new_user_input = "{error.a}"

# %%
my_class = MY_CLASS()
new_user_input.format(error=my_class)
# Out:
# '10'

# %% [markdown]
# If we don't want the user to access things he is not supposed to reach

# %% [markdown]
# **SAFE**

# %%
user_input = '${error.__init__.__global__[SECRET]}'

# %%
Template(user_input).substitute(error=err)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-3161a07a26dd> in <module>()
# ----> 1 Template(user_input).substitute(error=err)
#
# ~/anaconda/envs/py35/lib/python3.5/string.py in substitute(*args, **kws)
#     127             raise ValueError('Unrecognized named group in pattern',
#     128                              self.pattern)
# --> 129         return self.pattern.sub(convert, self.template)
#     130
#     131     def safe_substitute(*args, **kws):
#
# ~/anaconda/envs/py35/lib/python3.5/string.py in convert(mo)
#     124                 return self.delimiter
#     125             if mo.group('invalid') is not None:
# --> 126                 self._invalid(mo)
#     127             raise ValueError('Unrecognized named group in pattern',
#     128                              self.pattern)
#
# ...

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# to get the new viridis colorbar, I had to make sure I had the 1.5 version of matplotlib
# > conda install matplotlib
#
# NB:
# > pip install --upgrade matplotlib
#
# install matplotlib with success, but the pyplot module of matplotlib had an error and could not be used.

# %%
import matplotlib
matplotlib.__version__
# Out:
# '1.5.1'

# %%
image_file = '/Volumes/my_book_thunderbolt_duo/iBeatles/test_data/SHORT_Run19/Image019_00951.fits'

# %%
import os

# %%
print(os.path.isfile(image_file))
# Out:
# True

# %%
# pip install pyfits
import pyfits

# %%
hdu_list = pyfits.open(image_file)

# %%
print(hdu_list)
# Out:
# [<pyfits.hdu.image.PrimaryHDU object at 0x1159c4f90>]

# %%
# get viridis colormap

# %%
hdu = hdu_list[0]
plt.figure(figsize=(10,10))
plt.imshow(hdu.data, cmap='viridis')
plt.colorbar()

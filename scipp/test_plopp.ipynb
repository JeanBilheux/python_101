# %%
# %matplotlib widget
import scipp as sc
import plopp as pp
from plopp import widgets
from plopp.data import examples
from scipp.scipy.ndimage import gaussian_filter
import ipywidgets as ipw

data = sc.io.load_hdf5(examples.nyc_taxi())
data
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 5
#       3 import plopp as pp
#       4 from plopp import widgets
# ----> 5 from plopp.data import examples
#       6 from scipp.scipy.ndimage import gaussian_filter
#       7 import ipywidgets as ipw
#
# File ~/miniconda3/envs/python310/lib/python3.10/site-packages/plopp/data/examples.py:28
#      14     import pooch
#      16     return pooch.create(
#      17         path=pooch.os_cache('plopp'),
#      18         env='PLOPP_DATA_DIR',
#    (...)
#      24         },
#      25     )
# ---> 28 _pooch = _make_pooch()
#      31 def get_path(name: str) -> str:
#      32     """
#      33     Return the path to a data file bundled with plopp.
#      34
#      35     This function only works with example data and cannot handle
#      36     paths to custom files.
#      37     """
#
# File ~/miniconda3/envs/python310/lib/python3.10/site-packages/plopp/data/examples.py:14, in _make_pooch()
#      12 @lru_cache(maxsize=1)
#      13 def _make_pooch():
# ---> 14     import pooch
#      16     return pooch.create(
#      17         path=pooch.os_cache('plopp'),
#      18         env='PLOPP_DATA_DIR',
#    (...)
#      24         },
#      25     )
#
# ModuleNotFoundError: No module named 'pooch'

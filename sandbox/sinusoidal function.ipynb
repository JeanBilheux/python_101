# %%
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
x_range = np.arange(0,10,0.01)

# %%
plt.figure(1)
plt.plot(x_range, np.sin(np.pi*x_range))
plt.plot(x_range, np.sin(2*np.pi*x_range), '+')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
np.sin(0)
# Out:
# 0.0

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib notebook

# %%
def f(list):
    result = []
    for x in list:
        result.append(-5*x*x+35*x+150)
    return result

# %%
x_axis = np.arange(-10,20,0.1)

# %%
plt.plot(x_axis, f(x_axis))
# Out:
# <img src="data:image/png;base64,..." width="811">

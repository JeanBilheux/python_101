# %%
import os
import h5py
import plotly.express as px
import numpy as np

# %%
h5_file = "/Users/j35/Desktop/B1.h5"
h5_file = "/Users/j35/Desktop/B2.h5"
# h5_file = "/Users/j35/Desktop/B3.h5"
assert os.path.isfile(h5_file), f"File {h5_file} does not exist"

# %%
# Open the HDF5 file and read its contents
with h5py.File(h5_file, 'r') as f:
    # List all groups in the file
    print("Groups in the HDF5 file:")
    for group in f.keys():
        print(group)

    data_entry = f['entry']['data']
    
    data = np.array(data_entry['data'][:])
    # extract the array in data_entry
# Out:
# Groups in the HDF5 file:
# entry

# %%
print("Data shape:", data.shape )
print("Data type:", data.dtype)
print(f"total counts: {data.sum()}")
# Out:
# Data shape: (512, 512)
# Data type: uint64
# total counts: 493728918269

# %%
px.imshow(data, color_continuous_scale='Viridis', title='Data Visualization')

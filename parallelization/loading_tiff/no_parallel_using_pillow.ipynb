# %%
from PIL import Image
import glob
import time
import numpy as np

# %%
list_files = glob.glob('/Users/j35/IPTS/IPTS-21115/Huggies_redo_subset/*.tiff')
len(list_files)
# Out:
# 301

# %%
# %%time
image_array = []
for _file in list_files:
    _image = np.asarray(Image.open(_file))
    image_array.append(_image)
# Out:
# CPU times: user 3.2 s, sys: 3.65 s, total: 6.85 s
# Wall time: 15 s

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib notebook

# %%
image_array[100]
# Out:
# array([[123, 111, 127, ..., 111, 114, 122],
#        [113, 120, 120, ..., 119, 109, 121],
#        [122, 118, 127, ..., 120, 113, 112],
#        ...,
#        [101, 100, 105, ..., 103, 102, 102],
#        [104, 100, 100, ..., 103,  99, 100],
#        [104, 101, 102, ...,  99, 102,  95]], dtype=uint16)

# %%
plt.imshow(image_array[100])
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
from PyQt4 import QtGui

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
fig  = plt.figure(figsize=plt.figaspect(2.0))

# %%
fig.gca()

# %%
fig.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot([1,2,3,4],[10,20,25,30])
ax.set_xlim(0.5, 4.5)
plt.savefig("/users/j35/Desktop/remove_me.png")  #to save current figure to a file
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=plt.figaspect(0.5))
ax1.plot([-10, -5, 0, 5, 10, 15], [-1.2, 2, 3.5, -0.3, -4, 1])
ax2.scatter([-10, -5, 0, 5, 10, 15], [-1.2, 2, 3.5, -0.3, -4, 1])
plt.show()

# %%
# Good -- setting limits after plotting is done
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=plt.figaspect(0.5))
ax1.plot([-10, -5, 0, 5, 10, 15], [-1.2, 2, 3.5, -0.3, -4, 1])
ax2.scatter([-10, -5, 0, 5, 10, 15], [-1.2, 2, 3.5, -0.3, -4, 1])
ax1.set_ylim(bottom=-10)   # we can specify only one limite and let matlplotlib figure out the other end
ax2.set_xlim(right=25)
plt.show()
# set limit after plot to turn on autoscalling...otherwise, autoscalling is OFF

# %%
fig,ax=plt.subplots(1,1)
ax.set_ylim(1000,500)
plt.show()

# %%
# %matplotlib inline

# %%
# %matplotlib
# Out:
# Using matplotlib backend: module://IPython.kernel.zmq.pylab.backend_inline

# %%
fig,ax=plt.subplots(1,1)
ax.set_ylim(1000,500)
plt.show()

# %%
fig,axes= plt.subplots(3,2, sharex=True, sharey=True)
for ax in axes.flat : ax.plot(np.random.rand(10))

# %%
for ax in axes.flat : ax.plot(np.random.rand(10))

# %%
import os
from NeuNorm.normalization import Normalization
import matplotlib.pyplot as plt
# %matplotlib notebook
import numpy as np

# %%
high_resolution_file = "data/Norm03_40mmFOV.tif"
assert os.path.exists(high_resolution_file)

# %%
low_resolution_file = "data/Norm01_110mmFOV.tif"
assert os.path.exists(low_resolution_file)

# %%
o_load = Normalization()
o_load.load(file=high_resolution_file)
o_load.load(file=low_resolution_file)

data_high_resolution = o_load.data['sample']['data'][0]
data_low_resolution = o_load.data['sample']['data'][1]

# %%
plt.figure("high resolution")
plt.imshow(data_high_resolution)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure("low resolution")
plt.imshow(data_low_resolution)
# Out:
# <img src="data:image/png;base64,..." width="640">

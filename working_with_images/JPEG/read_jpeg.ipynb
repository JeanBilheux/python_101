# %%
import os
from PIL import Image
import numpy as np

import glob

import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
file1 = "data/image1.jpg"
assert os.path.exists(file1)

# %%
image = Image.open(file1)

# %%
image_array = np.array(image)

# %%
plt.imshow(image_array[:, :, :])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # trying to reproduce bug

# %%
input_folder = "/Volumes/G-DRIVE/work/2021/Venus/time_lapse/2020-11/"
assert os.path.exists(input_folder)

# %%
list_files = glob.glob(input_folder + "*.jpg")
print(f"len(list_files): {len(list_files)}")
# Out:
# len(list_files): 580

# %%
data_array = []
for _file in list_files:
    with Image.open(_file) as im:
        _data = np.asarray(im.convert('L'))
        data_array.append(_data)

# %%
np.shape(data_array)
# Out:
# (580, 1080, 1920)

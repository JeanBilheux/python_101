# %%
from PIL import Image
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib notebook

# %% [markdown]
# # User Input

# %%
y0 = 50
y1 = 300
x0 = 150
x1 = 250
counts = 20

width = 500
height = 700

# %% [markdown]
# where to create the image

# %% [markdown]
# Initialization of image

# %%
data = np.zeros((height, width))

# %% [markdown]
# home made data set with artifacts we can recognize easily

# %%
data[y0:y1, x0:x1] = counts

# %%
output_filename = '/Users/j35/Desktop/rectangle{}_y0_{}_y1_{}_x0_{}_x1_{}.tiff'.format(counts, y0, y1, x0, x1)

# %% [markdown]
# Let's check the image

# %%
fig, ax = plt.subplots(1,1)
plt.imshow(data)
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
new_image = Image.fromarray(data)
new_image.save(output_filename)

# %%
from PIL import Image
import numpy as np
from skimage import transform
import os

import matplotlib.pyplot as plt
# %matplotlib notebook

from NeuNorm.normalization import Normalization

# %% [markdown]
# # User Input

# %% [markdown]
# reference input file with metadata

# %%
input_file = "/Volumes/G-DRIVE/IPTS/IPTS-25967-pymbir/raw/radiographs/Aug25_2020/image1.tiff"
assert os.path.exists(input_file)

# %%
o_norm = Normalization()
o_norm.load(file=input_file, notebook=True)

# %% [markdown]
# Reference image

# %%
x0 = 500
y0 = 0
x1 = 1500 
y1 = 2047
counts01 = 100

width = 2048
height = 2048

tilt_angle = 0.1

# %% [markdown]
# where to create the image

# %% [markdown]
# Initialization of image

# %%
data = np.ones((height, width))

# %% [markdown]
# home made data set with artifacts we can recognize easily

# %%
data[y0:y1, x0:x1] = counts01
data = transform.rotate(data, tilt_angle)

# %% [markdown]
# Let's check the image

# %%
fig, ax = plt.subplots(1,1)
plt.imshow(data)
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
o_norm.data['sample']['file_name'] = ['image_0_1_tilt_0180.tiff']
new_image = data

o_norm.data['sample']['data'] = [new_image]
o_norm.export(folder="/Users/j35/Desktop", data_type='sample')

# new_image.save(output_filename)

# %%
#o_norm.data['sample']

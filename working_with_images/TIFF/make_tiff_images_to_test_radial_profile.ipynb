# %%
from PIL import Image
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib notebook

# %% [markdown]
# # User Input

# %% [markdown]
# Reference image

# %%
# center of circle
x0 = 500
y0 = 600

# size of image
width = 1000
height = 1000

# %%
# make array of distance of each pixel from center of circle

# %%
x = np.arange(width) + 0.5
y = np.arange(height) + 0.5

# %%
xv, yv = np.meshgrid(x, y)
distances_power = np.sqrt((np.power(yv - y0, 2) + np.power(xv - x0, 2)))

# %%
np.shape(distances_power)
# Out:
# (1000, 1000)

# %%
fig, ax = plt.subplots(1,1)
plt.imshow(distances_power)
plt.colorbar()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# export image

# %%
new_image = Image.fromarray(distances_power)
output_file_name = "/Users/j35/Desktop/circle_profile.tiff"
new_image.save(output_file_name)

# %% [markdown]
# # new set

# %%
distances_power_500 = np.sqrt((np.power(yv - y0, 2) + np.power(xv - x0, 2))) + 500

# %%
fig, ax = plt.subplots(1,1)
plt.imshow(distances_power_500)
plt.colorbar()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
new_image = Image.fromarray(distances_power_500)
output_file_name = "/Users/j35/Desktop/circle_profile_2.tiff"
new_image.save(output_file_name)

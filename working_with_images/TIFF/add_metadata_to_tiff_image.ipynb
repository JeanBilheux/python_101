# %% [markdown]
# # Learning how to load (PIL), manipulate data (numpy)  and save them back in tiff (16bits) (PIL)

# %% [markdown]
# Python Imaging Library (PIL) documentation can be found [here](http://effbot.org/imagingbook/pil-index.htm)

# %%
from PIL import Image

# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np

import time

# %%
filename = '/Users/j35/git/NeuNorm/tests/data/tif/sample/image002.tif'

# %% [markdown]
# # Loading image

# %%
image = Image.open(filename)
metadata_raw = dict(image.tag_v2)
image = np.array(image)
plt.figure()
plt.imshow(image)
plt.colorbar()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
print(metadata_raw)
# Out:
# {256: 5, 1: 'this is value a', 2: '5', 3: '5', 257: 5, 258: (32,), 259: 1, 262: 1, 273: (186,), 339: (3,), 278: 5, 279: (100,), 284: 1}

# %% [markdown]
# ## metadata to add

# %%
metadata_raw[1] = "this is metadata of image002.tif"

# %%
metadata = {1: 'this is value a',
            2: '5',
            3: '5'}

# %% [markdown]
# # Creating set of images

# %%
new_image = Image.fromarray(image)
new_image.save(filename, tiffinfo=metadata_raw)

# %% [markdown]
# # Test

# %%
new_image = Image.open(filename)
new_metadata = dict(new_image.tag_v2)
new_image = np.array(new_image)
plt.figure()
plt.imshow(new_image)
plt.colorbar()

print(new_metadata)
# Out:
# <img src="data:image/png;base64,..." width="640">
# {256: 5, 1: 'this is metadata of image002.tif', 2: '5', 3: '5', 257: 5, 258: (32,), 259: 1, 262: 1, 273: (204,), 339: (3,), 278: 5, 279: (100,), 284: 1}

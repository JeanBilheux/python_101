# %%
from PIL import Image

# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np

import time

# %%
filename = 'images/file_with_metadata_2018.tiff'

# %%
image = Image.open(filename)

# %%
plt.figure()
plt.imshow(image)
plt.colorbar()
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
from PIL.ExifTags import TAGS

# %%
info = image.tag.tags

# %%
image.tag_v2.tagtype
# Out:
# {256: 3,
#  257: 3,
#  258: 3,
#  259: 3,
#  262: 3,
#  271: 2,
#  272: 2,
#  273: 4,
#  277: 3,
#  278: 3,
#  279: 4,
#  284: 3,
#  305: 2,
#  339: 3,
#  65000: 12,
#  65001: 4,
#  65002: 4,
#  65003: 4,
#  65010: 2,
#  65011: 2,
#  65012: 2,
#  65013: 2,
#  65014: 2,
#  65015: 2,
#  65016: 2,
#  65017: 2,
#  65018: 2,
#  65019: 2,
#  65020: 2,
#  65021: 2,
#  65022: 2,
#  65023: 2,
#  65024: 2,
#  65025: 2,
#  65026: 2,
#  65027: 2,
#  65028: 2,
#  65029: 2,
#  65030: 2,
#  65031: 2,
#  65032: 2,
#  65033: 2,
#  65034: 2,
#  65035: 2,
#  65036: 2,
#  65037: 2,
#  65038: 2,
#  65039: 2,
#  65040: 2,
#  65041: 2,
#  65042: 2,
#  65043: 2,
#  65044: 2,
#  65045: 2,
#  65046: 2,
#  65047: 2,
#  65048: 2,
#  65049: 2,
#  65050: 2,
#  65051: 2,
#  65052: 2,
#  65053: 2,
#  65054: 2,
#  65055: 2,
#  65056: 2,
#  65057: 2,
#  65058: 2,
#  65059: 2,
#  65060: 2,
#  65061: 2,
#  65062: 2,
#  65063: 2,
#  65064: 2,
#  65065: 2,
#  65066: 2,
#  65067: 2,
#  65068: 2,
#  65069: 2,
#  65070: 2,
# ...

# %%
metadata = dict(image.tag_v2)

# %%
type(metadata)
# Out:
# dict

# %%
metadata
# Out:
# {256: 2048,
#  257: 2048,
#  258: (16,),
#  259: 1,
#  65024: 'NumImages:5',
#  65025: 'ImageCounter:1',
#  262: 1,
#  65026: 'MinX:0',
#  65027: 'MinY:0',
#  65028: 'SizeX:2048',
#  65029: 'SizeY:2048',
#  65030: 'Temperature:-60.000000',
#  65031: 'TemperatureActual:-59.777000',
#  65032: 'MotScanDeviceStr:Small Rot',
#  65033: 'RotationActual:182.984000',
#  271: 'Unknown',
#  272: 'Unknown',
#  273: (8,),
#  65034: 'MotLiftTable.RBV:226.991340',
#  65035: 'MotLiftTable:227.000000',
#  65036: 'MotShortAxis.RBV:29.812000',
#  277: 1,
#  278: 2048,
#  279: (8388608,),
#  65039: 'MotLongAxis:350.000000',
#  65040: 'MotRotTable.RBV:182.002500',
#  65041: 'MotRotTable:181.999500',
#  65042: 'MotSmallRotTable.RBV:182.984000',
#  284: 1,
#  65044: 'MotZaberRot.RBV:90.000743',
#  65045: 'MotZaberRot:90.000743',
#  65046: 'MotDetTable.RBV:200.000000',
#  65047: 'MotDetTable:200.000000',
#  65048: 'MotCameraVert.RBV:-51.699796',
#  65049: 'MotCameraVert:-51.699796',
# ...

# %%
output_file = 'images/new_file_with_metadata_2018.tiff'

# %%
new_image = np.array(image)

# %%
plt.figure()
plt.imshow(new_image)
plt.colorbar()
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
pillow_new_image = Image.fromarray(new_image)
pillow_new_image.save(output_file, tiffinfo=metadata)

# %% [markdown]
# # Checking that the write works

# %%
loaded_image = Image.open(output_file)

plt.figure()
plt.imshow(loaded_image)
plt.colorbar()
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
import pprint

# %%
metadata = dict(loaded_image.tag_v2)
pprint.pprint(metadata)
# Out:
# {256: 2048,
#  257: 2048,
#  258: (16,),
#  259: 1,
#  262: 1,
#  271: 'Unknown',
#  272: 'Unknown',
#  273: (2688,),
#  277: 1,
#  278: 2048,
#  279: (8388608,),
#  284: 1,
#  305: 'EPICS areaDetector',
#  339: (1,),
#  65000: 885012171.8068913,
#  65001: 1,
#  65002: 885012171,
#  65003: 817205355,
#  65010: 'FileNameStr:Sample2_Methane_150K_08Bar',
#  65011: 'InstrumentStr:CG1D',
#  65012: 'IPTS:18813',
#  65013: 'ITEMS:54195',
#  65014: 'SampleDescStr:Dark Field',
#  65015: 'NotesStr:Measured for CCD detector',
#  65016: 'DataSetStr:2D',
#  65017: 'DataAcqModeStr:White Beam',
#  65018: 'DataTypeStr:Raw',
#  65019: 'ModelStr:DW936_BV',
#  65020: 'ManufacturerStr:Andor',
#  65021: 'ExposureTime:30.000000',
#  65022: 'ExposurePeriod:34.451660',
#  65023: 'NumExposures:1',
#  65024: 'NumImages:5',
#  65025: 'ImageCounter:1',
#  65026: 'MinX:0',
#  65027: 'MinY:0',
#  65028: 'SizeX:2048',
#  65029: 'SizeY:2048',
#  65030: 'Temperature:-60.000000',
# ...

# %%
from PIL import Image
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib notebook

# %% [markdown]
# # User Input

# %%
height = 5
width = 5

# %% [markdown]
# Sample

# %% [markdown]
# Initialization of image

# %%
sample = np.ones((height, width))

# %%
sample[:, 0] = 1
sample[:, 1] = 2
sample[:, 2] = 3
sample[:, 3] = 4
sample[:, 4] = 5       
sample[0, 0] = 10
sample[4, 4] = 10

# %%
output_filename = '/Users/j35/Desktop/image_0001_roi_no_ob.tiff'

# %% [markdown]
# Let's check the image

# %%
fig, ax = plt.subplots(1,1)
plt.imshow(sample)
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
new_image = Image.fromarray(sample)
new_image.save(output_filename)

# %% [markdown]
# OB

# %%
ob = np.ones((height, width))

ob[0, 0] = 5
ob[4, 4] = 5

# %%
output_filename = '/Users/j35/Desktop/ob_0001_2rois.tiff'

# %%
fig, ax = plt.subplots(1,1)
plt.imshow(ob)
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
new_image = Image.fromarray(ob)
new_image.save(output_filename)

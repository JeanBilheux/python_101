# %%
from PIL import Image
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib notebook

# %% [markdown]
# # User Input

# %% [markdown]
# Reference image

# %%
x0 = 0
y0 = 0
x1 = 200 
y1 = 200
counts01 = 100

x2 = 200
y2 = 0
x3 = 400
y3 = 200
counts23 = 200

x4 = 200
y4 = 200
x5 = 400
y5 = 400
counts45 = 300

x6 = 0
y6 = 200
x7 = 200
y7 = 400 
counts67 = 400

width = 400
height = 400

# %% [markdown]
# where to create the image

# %% [markdown]
# Initialization of image

# %%
data = np.ones((height, width))

# %% [markdown]
# home made data set with artifacts we can recognize easily

# %%
data[y0:y1, x0:x1] = counts01
data[y2:y3, x2:x3] = counts23
data[y4:y5, x4:x5] = counts45
data[y6:y7, x6:x7] = counts67

# %%
output_filename = '/Users/j35/Desktop/image_0001.tiff'

# %% [markdown]
# Let's check the image

# %%
fig, ax = plt.subplots(1,1)
plt.imshow(data)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
output_filename = '/Users/j35/Desktop/image_0004.tiff'
new_image = Image.fromarray(data)
new_image.save(output_filename)

# %% [markdown]
# Target image

# %%
x0 = 200
y0 = 200
x1 = 499 
y1 = 300
counts = 20

x2 = 100
x3 = 150
y2 = 200
y3 = 300

xa = 50
xb = 450
ya = 600
yb = 750

xc = 200
yc = 600
xd = 400
yd = 750

width = 500
height = 800

# %%
data_target = np.ones((height, width))*100
data_target[y0:y1, x0:x1] = counts
data_target[y2:y3, x2:x3] = counts*2
data_target[ya:yb, xa:xb] = counts*5
data_target[yc:yd, xc:xd] = counts*10

# %%
output_filename = '/Users/j35/Desktop/image_0002.tiff'

# %%
fig, ax = plt.subplots(1,1)
plt.imshow(data_target)

# %%
new_image = Image.fromarray(data_target)
new_image.save(output_filename)

# %% [markdown]
# Help about [ravel](https://numpy.org/doc/stable/reference/generated/numpy.ravel.html)
#
# **Ravel** flatten an array

# %%
import numpy as np

# %%
xx, yy = np.meshgrid(np.linspace(-2*np.pi, 2*np.pi, 10),
                    np.linspace(-2*np.pi, 2*np.pi, 20))

# %%
np.shape(xx)
# Out:
# (20, 10)

# %%
xx
# Out:
# array([[-6.28318531, -4.88692191, -3.4906585 , -2.0943951 , -0.6981317 ,
#          0.6981317 ,  2.0943951 ,  3.4906585 ,  4.88692191,  6.28318531],
#        [-6.28318531, -4.88692191, -3.4906585 , -2.0943951 , -0.6981317 ,
#          0.6981317 ,  2.0943951 ,  3.4906585 ,  4.88692191,  6.28318531],
#        [-6.28318531, -4.88692191, -3.4906585 , -2.0943951 , -0.6981317 ,
#          0.6981317 ,  2.0943951 ,  3.4906585 ,  4.88692191,  6.28318531],
#        [-6.28318531, -4.88692191, -3.4906585 , -2.0943951 , -0.6981317 ,
#          0.6981317 ,  2.0943951 ,  3.4906585 ,  4.88692191,  6.28318531],
#        [-6.28318531, -4.88692191, -3.4906585 , -2.0943951 , -0.6981317 ,
#          0.6981317 ,  2.0943951 ,  3.4906585 ,  4.88692191,  6.28318531],
#        [-6.28318531, -4.88692191, -3.4906585 , -2.0943951 , -0.6981317 ,
#          0.6981317 ,  2.0943951 ,  3.4906585 ,  4.88692191,  6.28318531],
#        [-6.28318531, -4.88692191, -3.4906585 , -2.0943951 , -0.6981317 ,
# ...

# %%
np.shape(xx.ravel())
# Out:
# (200,)

# %%
xx.ravel()
# Out:
# array([-6.28318531, -4.88692191, -3.4906585 , -2.0943951 , -0.6981317 ,
#         0.6981317 ,  2.0943951 ,  3.4906585 ,  4.88692191,  6.28318531,
#        -6.28318531, -4.88692191, -3.4906585 , -2.0943951 , -0.6981317 ,
#         0.6981317 ,  2.0943951 ,  3.4906585 ,  4.88692191,  6.28318531,
#        -6.28318531, -4.88692191, -3.4906585 , -2.0943951 , -0.6981317 ,
#         0.6981317 ,  2.0943951 ,  3.4906585 ,  4.88692191,  6.28318531,
#        -6.28318531, -4.88692191, -3.4906585 , -2.0943951 , -0.6981317 ,
#         0.6981317 ,  2.0943951 ,  3.4906585 ,  4.88692191,  6.28318531,
#        -6.28318531, -4.88692191, -3.4906585 , -2.0943951 , -0.6981317 ,
#         0.6981317 ,  2.0943951 ,  3.4906585 ,  4.88692191,  6.28318531,
#        -6.28318531, -4.88692191, -3.4906585 , -2.0943951 , -0.6981317 ,
#         0.6981317 ,  2.0943951 ,  3.4906585 ,  4.88692191,  6.28318531,
#        -6.28318531, -4.88692191, -3.4906585 , -2.0943951 , -0.6981317 ,
# ...

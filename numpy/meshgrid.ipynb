# %%
import numpy as np
# %matplotlib notebook
import copy

# %%
x = np.arange(50) + 0.5
y = np.arange(50) + 0.5

# %%
x
# Out:
# array([ 0.5,  1.5,  2.5,  3.5,  4.5,  5.5,  6.5,  7.5,  8.5,  9.5, 10.5,
#        11.5, 12.5, 13.5, 14.5, 15.5, 16.5, 17.5, 18.5, 19.5, 20.5, 21.5,
#        22.5, 23.5, 24.5, 25.5, 26.5, 27.5, 28.5, 29.5, 30.5, 31.5, 32.5,
#        33.5, 34.5, 35.5, 36.5, 37.5, 38.5, 39.5, 40.5, 41.5, 42.5, 43.5,
#        44.5, 45.5, 46.5, 47.5, 48.5, 49.5])

# %%
xv, yv = np.meshgrid(x, y)

# %%
xv
# Out:
# array([[ 0.5,  1.5,  2.5, ..., 47.5, 48.5, 49.5],
#        [ 0.5,  1.5,  2.5, ..., 47.5, 48.5, 49.5],
#        [ 0.5,  1.5,  2.5, ..., 47.5, 48.5, 49.5],
#        ...,
#        [ 0.5,  1.5,  2.5, ..., 47.5, 48.5, 49.5],
#        [ 0.5,  1.5,  2.5, ..., 47.5, 48.5, 49.5],
#        [ 0.5,  1.5,  2.5, ..., 47.5, 48.5, 49.5]])

# %%
np.shape(yv)
# Out:
# (50, 50)

# %%
center = [10, 25]
distances = np.sqrt(np.power(xv - center[1], 2) + np.power(yv - center[0], 2))

# %%
import matplotlib.pyplot as plt

# %%
plt.figure("distances")
plt.imshow(distances)
plt.colorbar()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # create a mask

# %%
distances_masked = copy.deepcopy(distances)

mask1 = np.where(distances > 22)
for y, x in zip(mask1[0], mask1[1]):
    distances_masked[y, x] = 0

# %%
plt.figure("distances with simple mask")
plt.imshow(distances_masked)
plt.colorbar()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
distances_masked = copy.deepcopy(distances)

mask2 = np.where((distances > 22) & (distances < 24))
for y, x in zip(mask2[0], mask2[1]):
    distances_masked[y, x] = 0

# %%
plt.figure("distances with 2nd mask")
plt.imshow(distances_masked)
plt.colorbar()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# This notebook should demo how I can overlap several images and get the mean of the 2 images only when there are overlapping

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook
import copy

# %%
image1 = np.ones([10,10])
image1[0:5, 5:] = 5

image2 = np.ones([10,10])
image2[0:5, 0:5] = 10
image2[5:, 5:] = 5

fig, axes = plt.subplots(1,2)
axes[0].imshow(image1)
axes[1].imshow(image2)
# fig.colorbar()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
big_array1 = np.zeros((10,15))
big_array2 = np.zeros((10,15)) 
final_array = np.zeros((10,15))

# %%
big_array1[0:10, 0:10] = image1
big_array2[0:10, 5:15] = image2

fig, axes = plt.subplots(1,2)
axes[0].imshow(big_array1)
axes[1].imshow(big_array2)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
final_array = np.zeros((10,15))
where_big_array1_has_value = np.where(big_array1 != 0)
where_big_array2_has_value = np.where(big_array2 != 0)

big_array_multi = big_array1 * big_array2
value_in_array1_and_array2 = np.where(big_array_multi != 0)

# final_array[value_in_array1_and_array2] = 100
# fig, axes = plt.subplots(1,4)
# axes[0].imshow(final_array)

final_array = copy.deepcopy(big_array1)
final_array[value_in_array1_and_array2] = (big_array1[value_in_array1_and_array2] + big_array2[value_in_array1_and_array2])/2

# final_array_test_mask = copy.deepcopy(final_array)
# final_array_test_mask[value_in_array1_and_array2] = 100

fig, axes = plt.subplots(1,4)
axes[0].imshow(big_array1)
axes[1].imshow(big_array2)
axes[2].imshow(final_array_test_mask)
axes[3].imshow(final_array)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Method 2

# %%
# init images
image1 = np.ones([10,10])
image1[0:5, 5:] = 5

image2 = np.ones([10,10])
image2[0:5, 0:5] = 10
image2[5:, 5:] = 5

# big images
big_array1 = np.zeros((10,15))
big_array2 = np.zeros((10,15)) 
final_array = np.zeros((10,15))

big_array1[0:10, 0:10] = image1
big_array2[0:10, 5:15] = image2

# overlap
final_array = np.zeros((10,15))
where_big_array1_has_value_only = np.where((big_array1 != 0) & (big_array2 == 0))
where_big_array2_has_value_only = np.where((big_array2 != 0) & (big_array1 == 0))
where_big_array1_and_array2_has_value = np.where((big_array1 !=0) & (big_array2 != 0))


final_array[where_big_array1_has_value_only] = big_array1[where_big_array1_has_value_only]
final_array[where_big_array2_has_value_only] = big_array2[where_big_array2_has_value_only]
final_array[where_big_array1_and_array2_has_value] = (big_array1[where_big_array1_and_array2_has_value] +
                                                     big_array2[where_big_array1_and_array2_has_value])/2

fig, axes = plt.subplots(1, 3)
axes[0].imshow(big_array1)
axes[1].imshow(big_array2)
axes[2].imshow(final_array)
# Out:
# <img src="data:image/png;base64,..." width="640">
